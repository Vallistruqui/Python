# %% [markdown]
# **Intervalos de hoy en dia:**
#
#
# ```
# # frozen_string_literal: true
#
# module DeliveryEstimation
#   module Commons
#     def delta_minmax(index)
#       case index
#       when (0..4)
#         [8.minutes, 7.minutes]
#       when (5..9)
#         [12.minutes, 48.minutes]
#       when (10..19)
#         [24.minutes, 96.minutes]
#       else
#         [36.minutes, 144.minutes]
#       end
#     end
#   end
# end
# ```

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-39bdee3a-5110-465b-becd-2d8ab7ddf544" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39bdee3a-5110-465b-becd-2d8ab7ddf544">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HE OEF TI.csv to HE OEF TI.csv

# %%
import numpy as np
import pandas as pd

a1 = pd.read_csv('HE OEF TI.csv')

from scipy.stats import zscore
from scipy import stats

final = []

for travel_index in np.unique(a1.travel_index):


  df1 = a1[a1['travel_index']==travel_index]
  df1.reset_index(inplace= True,drop= True)

  # display(df1)  
  # z_scores = stats.zscore(df1)
  # abs_z_scores = np.abs(z_scores)
  # # print(abs_z_scores)
  # filtered_entries = (abs_z_scores < 0.5).all(axis=1)
  # print(len(filtered_entries), len(df1))
  # df1 = df1[filtered_entries]
  # display(df1)

  max_df1 = max(df1.error)
  min_df1 = min(df1.error)

  # print('Travel_Index: ',travel_index, ' Max: ',max_df1,' Min: ',min_df1)

  a = df1.error.astype(int)
  b = a
  a = pd.DataFrame(a)

  sup = []
  inf = []
  porcentaje_de_valores = []
  validez = []
  diff = []
  cantidad = []

  for q in range(0,20):

    sup.append(np.percentile(a,81+q, axis = 0)[0])
    
    for p in range(0,20):

      inf.append(np.percentile(a,19-p, axis = 0)[0])
      diff.append(sup[q]-inf[p])
      iv = pd.Interval(left=inf[p], right=sup[q])

      for y in range(0,len(b)): 
        validez.append(b[y] in iv)

      porcentaje_de_valores.append((len(b[validez])/len(b))*100)
      cantidad.append(len(b[validez]))
      validez = []
    
    globals()['Intervalos_1_%s' % q] = pd.DataFrame({'travel_index': travel_index, 'inf': inf, 'sup': sup[q], 'diff': diff,
                              'Captados_por_Este_Intervalo': cantidad, 'Total': len(b), 'porcentaje_de_valores': porcentaje_de_valores,
                              'Min_Intervalo': min_df1, 'Max_Intervalo': max_df1})
    inf = []
    porcentaje_de_valores = []
    diff = []
    cantidad = []

  accuracy_iv_1 = pd.Interval(left = 96, right=100)

  validez_accuracy_1_0 = []
  validez_accuracy_1_1 = []
  validez_accuracy_1_2 = []
  validez_accuracy_1_3 = []
  validez_accuracy_1_4 = []
  validez_accuracy_1_5 = []
  validez_accuracy_1_6 = []
  validez_accuracy_1_7 = []
  validez_accuracy_1_8 = []
  validez_accuracy_1_9 = []
  validez_accuracy_1_10 = []
  validez_accuracy_1_11 = []
  validez_accuracy_1_12 = []
  validez_accuracy_1_13 = []
  validez_accuracy_1_14 = []
  validez_accuracy_1_15 = []
  validez_accuracy_1_16 = []
  validez_accuracy_1_17 = []
  validez_accuracy_1_18 = []
  validez_accuracy_1_19 = []

  for r in range(0,20):
    validez_accuracy_1_0.append(Intervalos_1_0.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_1.append(Intervalos_1_1.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_2.append(Intervalos_1_2.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_3.append(Intervalos_1_3.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_4.append(Intervalos_1_4.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_5.append(Intervalos_1_5.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_6.append(Intervalos_1_6.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_7.append(Intervalos_1_7.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_8.append(Intervalos_1_8.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_9.append(Intervalos_1_9.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_10.append(Intervalos_1_10.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_11.append(Intervalos_1_11.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_12.append(Intervalos_1_12.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_13.append(Intervalos_1_13.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_14.append(Intervalos_1_14.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_15.append(Intervalos_1_15.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_16.append(Intervalos_1_16.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_17.append(Intervalos_1_17.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_18.append(Intervalos_1_18.porcentaje_de_valores[r] in accuracy_iv_1)
    validez_accuracy_1_19.append(Intervalos_1_19.porcentaje_de_valores[r] in accuracy_iv_1)

  vertical_stack_1 = pd.concat([Intervalos_1_0[validez_accuracy_1_0],
                              Intervalos_1_1[validez_accuracy_1_1],
                              Intervalos_1_2[validez_accuracy_1_2],
                              Intervalos_1_3[validez_accuracy_1_3],
                              Intervalos_1_4[validez_accuracy_1_4],
                              Intervalos_1_5[validez_accuracy_1_5],
                              Intervalos_1_6[validez_accuracy_1_6],
                              Intervalos_1_7[validez_accuracy_1_7],
                              Intervalos_1_8[validez_accuracy_1_8],
                              Intervalos_1_9[validez_accuracy_1_9],
                              Intervalos_1_10[validez_accuracy_1_10],
                              Intervalos_1_11[validez_accuracy_1_11],
                              Intervalos_1_12[validez_accuracy_1_12],
                              Intervalos_1_13[validez_accuracy_1_13],
                              Intervalos_1_14[validez_accuracy_1_14],
                              Intervalos_1_15[validez_accuracy_1_15],
                              Intervalos_1_16[validez_accuracy_1_16],
                              Intervalos_1_17[validez_accuracy_1_17],
                              Intervalos_1_18[validez_accuracy_1_18],
                              Intervalos_1_19[validez_accuracy_1_19]], axis=0)

  vertical_stack_1 = vertical_stack_1.sort_values(by = 'diff', ascending=True)
  try:
    vertical_stack_1 = vertical_stack_1[vertical_stack_1['diff']==min(vertical_stack_1['diff'])]
    final.append(vertical_stack_1)
    vertical_stack_1 = []
  
  except:
    final.append(vertical_stack_1)
    vertical_stack_1 = []
  
  # break
FINAL = pd.concat(final, axis = 0)
FINAL.reset_index(inplace= True,drop= True)
display(FINAL)
# Out:
#     travel_index     inf  ...  Min_Intervalo  Max_Intervalo
# 0              1 -681.00  ...         -948.0          816.0
# 1              2 -361.74  ...         -943.0          826.0
# 2              3 -324.56  ...         -935.0          819.0
# 3              4 -459.00  ...         -932.0          826.0
# 4              5 -924.00  ...         -924.0         1688.0
# ..           ...     ...  ...            ...            ...
# 68            69 -226.10  ...         -289.0         1096.0
# 69            70 -204.56  ...         -210.0         1110.0
# 70            71 -205.49  ...         -212.0         1116.0
# 71            72 -206.28  ...         -213.0         1124.0
# 72            73 -208.75  ...         -211.0         1145.0
#
# [73 rows x 9 columns]

# %%
FINAL.to_csv("Rangos por TI.csv")
FINAL.to_excel("Rangos por TI.xlsx")
files.download("Rangos por TI.csv")
files.download("Rangos por TI.xlsx")

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# x = list(FINAL.travel_index)
x = list(range(1, 101))

values1 = list(FINAL.Min_Intervalo)
values2 = list(FINAL.Max_Intervalo)

extrapolacion_100_max = max(FINAL.Max_Intervalo.tail(20))
extrapolacion_100_min = min(FINAL.Min_Intervalo.tail(20))

for i in range(0,100-len(values1)):
  values1.append(extrapolacion_100_min)

for i in range(0,100-len(values2)):
  values2.append(extrapolacion_100_max)

fig = plt.figure(figsize = (30, 10))

plt.plot(x, values1, 'go--', label = 'Maximo', markersize = 5, linestyle = 'dashed',  linewidth=5)
plt.plot(x, values2, 'go--', label = 'Minimo', markersize = 5, linestyle = 'dashed',  linewidth=5)

plt.xlabel("Travel Index")
plt.ylabel("Error")
plt.title("Intervalos por TI al 100%")
plt.show()
#----------------------------------------------------------------------------------------
  
values3  = list(FINAL.inf)
values4  = list(FINAL.sup)
values5 = []
values6 = []

extrapolacion_96_max = max(FINAL.sup.tail(20))
extrapolacion_96_min = min(FINAL.inf.tail(20))

for i in range(0,100-len(values3)):
  values3.append(extrapolacion_96_min)

for i in range(0,100-len(values4)):
  values4.append(extrapolacion_96_max)

for i in values3:
  values5.append(i * 1.1)

for i in values4:
  values6.append(i * 1.1)

fig2 = plt.figure(figsize = (30, 10))

plt.plot(x, values3, 'go--', label = 'Maximo', markersize = 5,  linestyle = 'dashed',  linewidth=5)
plt.plot(x, values5, 'r--' , label = 'Maximo', markersize = 5,  linewidth = 1)

plt.plot(x, values4, 'go--', label = 'Minimo', markersize = 5,  linestyle = 'dashed',  linewidth=5)
plt.plot(x, values6, 'r--' , label = 'Maximo', markersize = 5,  linewidth = 1)

plt.xlabel("Travel Index")
plt.ylabel("Error")
plt.title("Intervalos por TI al 96%")
plt.show()

valuesX3 = values3
valuesX4 = values4

for posicion in range(0,5):
  valuesX3[posicion] = min(values3[0:5]) 
  valuesX4[posicion] = max(values4[0:5])

for posicion in range(5,16):
  valuesX3[posicion] = min(values3[5:16]) 
  valuesX4[posicion] = max(values4[5:16])

for posicion in range(16,26):
  valuesX3[posicion] = min(values3[16:26]) 
  valuesX4[posicion] = max(values4[16:26])

for posicion in range(26,36):
  valuesX3[posicion] = min(values3[26:36]) 
  valuesX4[posicion] = max(values4[26:36])

for posicion in range(36,46):
  valuesX3[posicion] = min(values3[36:46]) 
  valuesX4[posicion] = max(values4[36:46])

for posicion in range(46,66):
  valuesX3[posicion] = min(values3[46:66]) 
  valuesX4[posicion] = max(values4[46:66])

for posicion in range(66,100):
  valuesX3[posicion] = min(values3[66:100]) 
  valuesX4[posicion] = max(values4[66:100])

fig3 = plt.figure(figsize = (30, 10))

plt.plot(x, valuesX3, 'go--', label = 'Maximo', markersize = 5,  linestyle = 'dashed',  linewidth=5)
plt.plot(x, valuesX4, 'go--', label = 'Minimo', markersize = 5,  linestyle = 'dashed',  linewidth=5)

plt.xlabel("Travel Index")
plt.ylabel("Error")
plt.title("Intervalos por TI al 96%")
plt.show()

intervalos = ['1-5','6-15','16-25','26-35','36-45','46-100']

df = pd.DataFrame({'intervalos': intervalos, 'sup': list(dict.fromkeys(valuesX4)), 'inf': list(dict.fromkeys(valuesX3))})

display(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ea1d3bede174> in <module>()
#     104 intervalos = ['1-5','6-15','16-25','26-35','36-45','46-100']
#     105
# --> 106 df = pd.DataFrame({'intervalos': intervalos, 'sup': list(dict.fromkeys(valuesX4)), 'inf': list(dict.fromkeys(valuesX3))})
#     107
#     108 display(df)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
df.to_csv("Rangos por TI.csv")
df.to_excel("Rangos por TI.xlsx")
files.download("Rangos por TI.csv")
files.download("Rangos por TI.xlsx")

# %% [markdown]
# ```
# #frozen_string_literal: true
#
# module DeliveryEstimation
#   module Commons
#     def delta_minmax(index)
#       case index
#       when (1..5)
#         [41.minutes, 214.minutes]
#       when (6..15)
#         [77.minutes, 235.minutes]
#       when (16..25)
#         [102.minutes, 216.minutes]
#       when (26..35)
#         [129.minutes, 117.minutes]
#       when (36..45)*
#         [145.minutes, 97.minutes]
#       else
#         [163.minutes, 109.minutes]
#       end
#     end
#   end
# end
#
# ```
