# %% [markdown]
# <a href="https://colab.research.google.com/github/Vallistruquibienpiola/Python/blob/main/RSI_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install python-binance
# !pip install websocket_client

# %% [markdown]
# Importado de TA-Lib

# %%
# url = 'https://anaconda.org/conda-forge/libta-lib/0.4.0/download/linux-64/libta-lib-0.4.0-h516909a_0.tar.bz2'
# !curl -L $url | tar xj -C /usr/lib/x86_64-linux-gnu/ lib --strip-components=1
# url = 'https://anaconda.org/conda-forge/ta-lib/0.4.19/download/linux-64/ta-lib-0.4.19-py37ha21ca33_2.tar.bz2'
# !curl -L $url | tar xj -C /usr/local/lib/python3.7/dist-packages/ lib/python3.7/site-packages/talib --strip-components=3

# %% [markdown]
# Llamando a todas las librerias necesarias

# %%
import websocket, json, pprint

# %%
SOCKET = "wss://stream.binance.com:9443/ws/ethusdt@kline_1m"

closes = []

def on_open(ws):
    print('opened connection')

def on_close(ws):
    print('closed connection')

def on_message(ws, message):    
    print('received message')
    json_message = json.loads(message)
    pprint.pprint(json_message)

    candle = json_message['k']
    is_candle_closed = candle['x']
    close = candle['c']

    if is_candle_closed:
        print("candle closed at {}".format(close))
        closes.append(float(close))
        print("closes")
        print(closes)

ws = websocket.WebSocketApp(SOCKET, on_open=on_open, on_close=on_close, on_message=on_message)
ws.run_forever()
# Out:
# Streaming output truncated to the last 5000 lines.
#        'L': 581962967,
#        'Q': '306030.51128500',
#        'T': 1630428659999,
#        'V': '89.95980000',
#        'c': '3401.17000000',
#        'f': 581962152,
#        'h': '3403.90000000',
#        'i': '1m',
#        'l': '3400.78000000',
#        'n': 816,
#        'o': '3403.90000000',
#        'q': '848396.53670100',
#        's': 'ETHUSDT',
#        't': 1630428600000,
#        'v': '249.39610000',
#        'x': False},
#  's': 'ETHUSDT'}
# received message
# {'E': 1630428636593,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 581962984,
#        'Q': '307738.22412000',
#        'T': 1630428659999,
#        'V': '90.46190000',
#        'c': '3401.14000000',
#        'f': 581962152,
#        'h': '3403.90000000',
#        'i': '1m',
#        'l': '3400.78000000',
#        'n': 833,
#        'o': '3403.90000000',
#        'q': '853726.12975400',
#        's': 'ETHUSDT',
#        't': 1630428600000,
# ...
